# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x = np.random.randint(10,60,(50))
print(x)

# %%
no = [29,24,23, 48, 52, 56, 44, 35, 55, 49, 39, 30, 14, 28, 11, 44, 41, 28, 47, 16, 34, 58, 30, 20,
 43, 31, 25, 13, 30, 52, 49, 14, 32 ,18, 24, 38, 35, 35, 48, 13, 46, 53, 47, 10, 40, 41, 44, 26, 
16, 28]

plt.title('histogram', fontsize = 15)
plt.xlabel('pyhton', fontsize = 15)
plt.ylabel('no.', fontsize = 15)

plt.hist(no,color = 'g')
plt.show()

# %%
no = [29,24,23, 48, 52, 56, 44, 35, 55, 49, 39, 30, 14, 28, 11, 44, 41, 28, 47, 16, 34, 58, 30, 20,
 43, 31, 25, 13, 30, 52, 49, 14, 32 ,18, 24, 38, 35, 35, 48, 13, 46, 53, 47, 10, 40, 41, 44, 26, 
16, 28]


plt.title('histogram', fontsize = 15)
plt.xlabel('pyhton', fontsize = 15)
plt.ylabel('no.', fontsize = 15)

plt.hist(no ,color = 'r' ,edgecolor = 'g')
plt.show()

# %%
no = [29,24,23, 48, 52, 56, 44, 35, 55, 49, 39, 30, 14, 28, 11, 44, 41, 28, 47, 16, 34, 58, 30, 20,
 43, 31, 25, 13, 30, 52, 49, 14, 32 ,18, 24, 38, 35, 35, 48, 13, 46, 53, 47, 10, 40, 41, 44, 26, 
16, 28]

l = [10,20,30,40,50,60]

plt.title('histogram', fontsize = 15)
plt.xlabel('pyhton', fontsize = 15)
plt.ylabel('no.', fontsize = 15)

plt.hist(no ,color = 'r' ,edgecolor = 'g' , bins = l, label = 'python')
plt.legend()
plt.show()

# %%
no = [29,24,23, 48, 52, 56, 44, 35, 55, 49, 39, 30, 14, 28, 11, 44, 41, 28, 47, 16, 34, 58, 30, 20,
 43, 31, 25, 13, 30, 52, 49, 14, 32 ,18, 24, 38, 35, 35, 48, 13, 46, 53, 47, 10, 40, 41, 44, 26, 
16, 28]

l = [10,20,30,40,50,60]

plt.title('histogram', fontsize = 15)
plt.xlabel('pyhton', fontsize = 15)
plt.ylabel('no.', fontsize = 15)

plt.hist(no , 'auto', (0,200),edgecolor = 'g')
plt.show()

# %%
no = [29,24,23, 48, 52, 56, 44, 35, 55, 49, 39, 30, 14, 28, 11, 44, 41, 28, 47, 16, 34, 58, 30, 20,
 43, 31, 25, 13, 30, 52, 49, 14, 32 ,18, 24, 38, 35, 35, 48, 13, 46, 53, 47, 10, 40, 41, 44, 26, 
16, 28]

l = [10,20,30,40,50,60]

plt.title('histogram', fontsize = 15)
plt.xlabel('pyhton', fontsize = 15)
plt.ylabel('no.', fontsize = 15)

plt.hist(no ,color = 'r' ,edgecolor = 'g', cumulative = -1 )
plt.show()

# %%
no = [29,24,23, 48, 52, 56, 44, 35, 55, 49, 39, 30, 14, 28, 11, 44, 41, 28, 47, 16, 34, 58, 30, 20,
 43, 31, 25, 13, 30, 52, 49, 14, 32 ,18, 24, 38, 35, 35, 48, 13, 46, 53, 47, 10, 40, 41, 44, 26, 
16, 28]

l = [10,20,30,40,50,60]

plt.title('histogram', fontsize = 15)
plt.xlabel('pyhton', fontsize = 15)
plt.ylabel('no.', fontsize = 15)

plt.hist(no ,color = 'r' ,edgecolor = 'g' , bottom = 10, align = 'mid',log = True,histtype = 'step')
plt.show()

# %%
no = [29,24,23, 48, 52, 56, 44, 35, 55, 49, 39, 30, 14, 28, 11, 44, 41, 28, 47, 16, 34, 58, 30, 20,
 43, 31, 25, 13, 30, 52, 49, 14, 32 ,18, 24, 38, 35, 35, 48, 13, 46, 53, 47, 10, 40, 41, 44, 26, 
16, 28]

l = [10,20,30,40,50,60]

plt.title('histogram', fontsize = 15)
plt.xlabel('pyhton', fontsize = 15)
plt.ylabel('no.', fontsize = 15)

plt.hist(no ,color = 'r' ,edgecolor = 'g' , orientation = 'horizontal')
plt.show()

# %%
no = [29,24,23, 48, 52, 56, 44, 35, 55, 49, 39, 30, 14, 28, 11, 44, 41, 28, 47, 16, 34, 58, 30, 20,
 43, 31, 25, 13, 30, 52, 49, 14, 32 ,18, 24, 38, 35, 35, 48, 13, 46, 53, 47, 10, 40, 41, 44, 26, 
16, 28]

l = [10,20,30,40,50,60]

plt.title('histogram', fontsize = 15)
plt.xlabel('pyhton', fontsize = 15)
plt.ylabel('no.', fontsize = 15)

plt.hist(no ,color = 'r' ,edgecolor = 'g',rwidth = 0.8, label = 'python') 

plt.axvline(45,color = 'g')
plt.legend()
plt.show()
